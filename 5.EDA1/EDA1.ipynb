# %%
'''Inspect the dataset: Check for missing values and data types.'''
# Out:
# 'Inspect the dataset: Check for missing values and data types.'

# %%
import pandas as pd

# Load the dataset into a DataFrame
file_path ='Cardiotocographic.csv'
df = pd.read_csv(file_path)

# %%
# Display the first few rows of the dataset
df.head()
# Out:
#            LB        AC   FM        UC        DL   DS   DP  ASTV  MSTV  ALTV  \
# 0  120.000000  0.000000  0.0  0.000000  0.000000  0.0  0.0  73.0   0.5  43.0
# 1  132.000000  0.006380  0.0  0.006380  0.003190  0.0  0.0  17.0   2.1   0.0
# 2  133.000000  0.003322  0.0  0.008306  0.003322  0.0  0.0  16.0   2.1   0.0
# 3  134.000000  0.002561  0.0  0.007742  0.002561  0.0  0.0  16.0   2.4   0.0
# 4  131.948232  0.006515  0.0  0.008143  0.000000  0.0  0.0  16.0   2.4   0.0
#
#    MLTV  Width  Tendency  NSP
# 0   2.4   64.0  0.999926  2.0
# 1  10.4  130.0  0.000000  1.0
# 2  13.4  130.0  0.000000  1.0
# 3  23.0  117.0  1.000000  1.0
# 4  19.9  117.0  1.000000  1.0

# %%
print(df.dtypes)
# Out:
# LB          float64
# AC          float64
# FM          float64
# UC          float64
# DL          float64
# DS          float64
# DP          float64
# ASTV        float64
# MSTV        float64
# ALTV        float64
# MLTV        float64
# Width       float64
# Tendency    float64
# NSP         float64
# dtype: object

# %%
# Handle missing values by filling with the mean of the respective columns
df.fillna(df.mean(), inplace=True)

# Verify that there are no missing values left
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2126 non-null   float64
#  1   AC        2126 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2126 non-null   float64
#  6   DP        2126 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2126 non-null   float64
#  11  Width     2126 non-null   float64
#  12  Tendency  2126 non-null   float64
#  13  NSP       2126 non-null   float64
# dtypes: float64(14)
# memory usage: 232.7 KB

# %%
# Display the summary statistics and data types of the dataset
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2126 non-null   float64
#  1   AC        2126 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2126 non-null   float64
#  6   DP        2126 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2126 non-null   float64
#  11  Width     2126 non-null   float64
#  12  Tendency  2126 non-null   float64
#  13  NSP       2126 non-null   float64
# dtypes: float64(14)
# memory usage: 232.7 KB
#                 LB           AC           FM           UC           DL  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Histogram
df_cleaned.hist(figsize=(15, 10))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 5
#       2 import seaborn as sns
#       4 # Histogram
# ----> 5 df_cleaned.hist(figsize=(15, 10))
#       6 plt.show()
#
# NameError: name 'df_cleaned' is not defined

# %%
def detect_and_treat_outliers(df):
    for column in df.columns:
        Q1 = df[column].quantile(0.25)
        Q3 = df[column].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        df[column] = df[column].clip(lower=lower_bound, upper=upper_bound)
    return df

df_cleaned = detect_and_treat_outliers(df)
df_cleaned.describe()

# %%
# Box plots
df_cleaned.plot(kind='box', subplots=True, layout=(4, 4), figsize=(15, 10), sharex=False, sharey=False)
plt.show()

# %%
# Correlation heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(df_cleaned.corr(), annot=True, fmt=".2f")
plt.show()
sns.pairplot(df_cleaned)
plt.show()

# %%
def detect_and_treat_outliers(df):
    for column in df.columns:
        # Calculate Q1 (25th percentile) and Q3 (75th percentile)
        Q1 = df[column].quantile(0.25)
        Q3 = df[column].quantile(0.75)
        
        # Calculate the IQR
        IQR = Q3 - Q1
        
        # Define the lower and upper bounds for outliers
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        
        # Cap the outliers
        df[column] = df[column].clip(lower=lower_bound, upper=upper_bound)
    
    return df

# %%
# Apply the function to detect and treat outliers
df_cleaned = detect_and_treat_outliers(df)

# %%
# Verify the changes by displaying summary statistics again
df_cleaned.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean    133.293725     0.003147     0.001568     0.004362     0.001770
# std       9.930227     0.003826     0.002485     0.003001     0.002668
# min     105.000000    -0.008409    -0.003850    -0.005177    -0.004934
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001668     0.000000     0.004484     0.000000
# 75%     140.000000     0.005606     0.002567     0.006536     0.003289
# max     161.000000     0.014015     0.006416     0.013564     0.008224
#
#            DS      DP         ASTV         MSTV         ALTV         MLTV  \
# count  2126.0  2126.0  2126.000000  2126.000000  2126.000000  2126.000000
# mean      0.0     0.0    46.981873     1.304644     6.691678     8.016212
# std       0.0     0.0    17.612745     0.781091    10.378400     5.046784
# ...

# %%
# Generate statistical summary
summary = df.describe()

# %%
# Add median to the summary
median = df.median()
summary.loc['median'] = median

# %%
# Add interquartile range (IQR) to the summary
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
summary.loc['IQR'] = IQR

# %%
# Print the summary
print(summary)
# Out:
#                  LB           AC           FM           UC           DL  \
# count   2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean     133.343598     0.003219     0.009894     0.004391     0.001895
# std       11.214328     0.004370     0.067540     0.003340     0.003343
# min       51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%      126.000000     0.000000     0.000000     0.001851     0.000000
# 50%      133.000000     0.001668     0.000000     0.004484     0.000000
# 75%      140.000000     0.005606     0.002567     0.006536     0.003289
# max      214.000000     0.038567     0.961268     0.030002     0.030769
# median   133.000000     0.001668     0.000000     0.004484     0.000000
# IQR       14.000000     0.005606     0.002567     0.004685     0.003289
#
#                  DS           DP         ASTV         MSTV         ALTV  \
# count   2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Calculate correlation matrix
correlation_matrix = df.corr()

# %%
# Visualize correlations using a heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
# Identify significant correlations
significant_correlations = correlation_matrix[abs(correlation_matrix) > 0.5]
print("Significant Correlations:")
print(significant_correlations)

# Explore temporal trends if available
# Example: Plot time series for a specific variable
# plt.figure(figsize=(12, 6))
# plt.plot(df['Date'], df['Variable'], marker='o', linestyle='-')
# plt.title('Time Series Plot')
# plt.xlabel('Date')
# plt.ylabel('Variable')
# plt.show()
# Out:
# Significant Correlations:
#            LB   AC   FM   UC   DL   DS   DP  ASTV  MSTV  ALTV  MLTV  Width  \
# LB        1.0  NaN  NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN    NaN
# AC        NaN  1.0  NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN    NaN
# FM        NaN  NaN  1.0  NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN    NaN
# UC        NaN  NaN  NaN  1.0  NaN  NaN  NaN   NaN   NaN   NaN   NaN    NaN
# DL        NaN  NaN  NaN  NaN  1.0  NaN  NaN   NaN   NaN   NaN   NaN    NaN
# DS        NaN  NaN  NaN  NaN  NaN  1.0  NaN   NaN   NaN   NaN   NaN    NaN
# DP        NaN  NaN  NaN  NaN  NaN  NaN  1.0   NaN   NaN   NaN   NaN    NaN
# ASTV      NaN  NaN  NaN  NaN  NaN  NaN  NaN   1.0   NaN   NaN   NaN    NaN
# MSTV      NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN   1.0   NaN   NaN    NaN
# ALTV      NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN   NaN   1.0   NaN    NaN
# MLTV      NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN   1.0    NaN
# ...

# %%
# Create histograms for numerical variables
numerical_vars = df.select_dtypes(include=['float64'])
numerical_vars.hist(figsize=(12, 10))
plt.tight_layout()
plt.show()

# %%
# Create boxplots for numerical variables
plt.figure(figsize=(12, 10))
sns.boxplot(data=numerical_vars)
plt.xticks(rotation=45)
plt.show()

# %%
# Create bar charts or pie charts for categorical variables
categorical_vars = df.select_dtypes(include=['object'])
for column in categorical_vars.columns:
    plt.figure(figsize=(8, 6))
    df[column].value_counts().plot(kind='bar', color='skyblue')
    plt.title(column)
    plt.xlabel('Categories')
    plt.ylabel('Frequency')
    plt.xticks(rotation=45)
    plt.show()

# %%
# Generate scatter plots or correlation heatmaps
plt.figure(figsize=(12, 10))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
# Employ advanced visualization techniques like pair plots or violin plots
sns.pairplot(df)
plt.show()
plt.figure(figsize=(12, 10))
sns.violinplot(data=numerical_vars, inner="points")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Reshma\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Calculate correlation matrix
correlation_matrix = df.corr()

# %%
# Visualize correlations using a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
# Look for significant correlations
# Identify correlations above a certain threshold (e.g., 0.5 or -0.5)
significant_correlations = correlation_matrix[(correlation_matrix > 0.5) | (correlation_matrix < -0.5)]
print("Significant Correlations:")
print(significant_correlations)
# Out:
# Significant Correlations:
#            LB   AC   FM   UC   DL   DS   DP  ASTV  MSTV  ALTV  MLTV  Width  \
# LB        1.0  NaN  NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN    NaN
# AC        NaN  1.0  NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN    NaN
# FM        NaN  NaN  1.0  NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN    NaN
# UC        NaN  NaN  NaN  1.0  NaN  NaN  NaN   NaN   NaN   NaN   NaN    NaN
# DL        NaN  NaN  NaN  NaN  1.0  NaN  NaN   NaN   NaN   NaN   NaN    NaN
# DS        NaN  NaN  NaN  NaN  NaN  1.0  NaN   NaN   NaN   NaN   NaN    NaN
# DP        NaN  NaN  NaN  NaN  NaN  NaN  1.0   NaN   NaN   NaN   NaN    NaN
# ASTV      NaN  NaN  NaN  NaN  NaN  NaN  NaN   1.0   NaN   NaN   NaN    NaN
# MSTV      NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN   1.0   NaN   NaN    NaN
# ALTV      NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN   NaN   1.0   NaN    NaN
# MLTV      NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN   1.0    NaN
# ...

# %%
# Look for trends or patterns over time (if temporal data is available)
# Example: Plot time series for a specific variable
# plt.figure(figsize=(12, 6))
# plt.plot(df['Date'], df['Variable'], marker='o', linestyle='-')
# plt.title('Time Series Plot')
# plt.xlabel('Date')
# plt.ylabel('Variable')
# plt.show()

# %%
'''From the significant correlations identified:

1. **Baseline Fetal Heart Rate (LB)**:
   - It shows a perfect positive correlation with itself, which is expected since it's the same variable.

2. **Accelerations (AC)**, **Fetal Movements (FM)**, **Uterine Contractions (UC)**, **Decelerations Late (DL)**, 
**Mean Value of Short Term Variability (MSTV)**, **Width**:
   - There are no significant correlations identified with other variables based on the given correlation matrix.

3. **Percentage of Time with Abnormal Short Term Variability (ASTV)**:
   - It shows a perfect positive correlation with itself, which is expected since it's the same variable.

4. **Percentage of Time with Abnormal Long Term Variability (ALTV)**:
   - It shows a perfect positive correlation with itself, which is expected since it's the same variable.
   - It also has a negative correlation with MSTV, indicating that abnormal long-term variability might be associated with 
   lower mean short-term variability.

5. **Mean Value of Long Term Variability (MLTV)**:
   - It shows a perfect positive correlation with itself, which is expected since it's the same variable.

6. **Tendency**:
   - It shows a perfect positive correlation with itself, which is expected since it's the same variable.

7. **NSP (Fetal State Class)**:
   - There are no significant correlations identified with other variables based on the given correlation matrix.

These findings suggest that in this dataset, most variables do not exhibit strong correlations with each other. 
However, it's important to note that correlation does not imply causation, and further analysis may be needed to understand 
the relationships between variables and their potential implications. Additionally, the absence of significant correlations 
does not necessarily mean the absence of relationships; it may indicate non-linear or more complex relationships that require 
different analytical approaches.'''
# Out:
# "From the significant correlations identified:\n\n1. **Baseline Fetal Heart Rate (LB)**:\n   - It shows a perfect positive correlation with itself, which is expected since it's the same variable.\n\n2. **Accelerations (AC)**, **Fetal Movements (FM)**, **Uterine Contractions (UC)**, **Decelerations Late (DL)**, \n**Mean Value of Short Term Variability (MSTV)**, **Width**:\n   - There are no significant correlations identified with other variables based on the given correlation matrix.\n\n3. **Percentage of Time with Abnormal Short Term Variability (ASTV)**:\n   - It shows a perfect positive correlation with itself, which is expected since it's the same variable.\n\n4. **Percentage of Time with Abnormal Long Term Variability (ALTV)**:\n   - It shows a perfect positive correlation with itself, which is expected since it's the same variable.\n   - It also has a negative correlation with MSTV, indicating that abnormal long-term variability might be associated with \n   lower mean short-te
# ...
